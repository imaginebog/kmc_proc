# %%
lista_pablo={8, 9, 15, 25, 29, 31, 35, 44, 53, 54, 56, 65, 69, 71, 72, 75, 83, 90, 93, 107, 108, 113, 119, 123, 124, 125, 129, 134, 141, 143, 144, 145, 149, 151, 153, 154, 157, 161, 172, 175, 176, 182, 185, 186, 195, 197, 201, 202, 210, 212, 235, 253, 261, 263, 266, 277, 288, 293, 301, 304, 307, 310, 312, 313, 314, 319, 320, 327, 333, 346, 353, 355, 356, 356, 358, 364, 369, 371, 374, 381, 390, 396, 402, 413, 416, 417, 423, 424, 429, 431, 432, 440, 452, 456, 458, 464, 469, 472, 478, 480, 483, 484, 485, 491, 496, 499, 504, 526, 532, 535, 536, 537, 542, 544, 545, 547, 548, 549, 552, 566, 568, 576, 577, 579, 580, 592, 593, 595, 598, 599, 600, 602, 610, 611, 615, 616, 619, 623, 625, 630, 631, 645, 650, 651, 662, 665, 670, 675, 678, 684, 686, 689, 691, 694, 696, 712, 715, 734, 739, 752, 754, 761, 765, 769, 783, 784, 786, 789, 790, 791, 795, 799, 804, 806, 815, 818, 821, 829, 840, 841, 861, 863, 868, 869, 874, 876, 877, 878, 879, 884, 892, 893, 894, 898, 905, 906, 913, 914, 918, 928, 934, 939, 940, 942, 953, 954, 965, 966, 971, 982, 984, 992, 994, 1005, 1006, 1021, 1026, 1039, 1049, 1063, 1076, 1077, 1212, 1213, 1221, 1224, 1227, 1232, 1234, 1237, 1239, 1242, 1244, 1247, 1251, 1253, 1265, 1267, 1269, 1271, 1278, 1304, 1318, 1320, 1326, 1333, 1336, 1337, 1338, 1340, 1357}

# %%
in_master={1005,  1006,  1021,  1026,  1039,  1049,  1063,  1076,  1077,  107,  113,  119,  1212,  1213,  1221,  1224,  1227,  1232,  1234,  1237,  1239,  123,  1242,  1244,  1247,  124,  1251,  1253,  125,  1265,  1267,  1269,  1271,  1278,  129,  1304,  1318,  1320,  1326,  1333,  1336,  1337,  1338,  1340,  134,  1357,  141,  143,  144,  145,  149,  151,  153,  154,  157,  15,  161,  172,  175,  176,  182,  185,  186,  195,  197,  201,  202,  210,  212,  235,  253,  25,  261,  263,  266,  277,  288,  293,  29,  301,  304,  307,  310,  312,  313,  314,  319,  31,  320,  327,  333,  346,  353,  355,  356,  358,  35,  364,  369,  371,  374,  381,  390,  396,  402,  413,  416,  417,  423,  424,  429,  431,  432,  440,  44,  452,  456,  458,  464,  469,  472,  478,  480,  483,  484,  485,  491,  496,  499,  504,  526,  532,  535,  536,  537,  53,  542,  544,  545,  547,  548,  549,  54,  552,  566,  568,  56,  576,  577,  579,  580,  592,  593,  595,  598,  599,  600,  602,  610,  611,  615,  616,  619,  623,  625,  630,  631,  645,  650,  651,  65,  662,  665,  670,  675,  678,  684,  686,  689,  691,  694,  696,  69,  712,  715,  71,  72,  730,  734,  739,  752,  754,  75,  761,  765,  769,  783,  784,  786,  789,  790,  791,  795,  799,  804,  806,  815,  818,  821,  829,  83,  840,  841,  861,  863,  868,  869,  874,  876,  877,  878,  879,  884,  892,  893,  894,  898,  8,  905,  906,  90,  913,  914,  918,  928,  934,  939,  93,  940,  942,  953,  954,  964,  965,  966,  971,  982,  984,  992,  994,  9,   }

# %%
faltantes = lista_pablo - in_master

# %%
sobrantes = in_master - lista_pablo

# %%
print faltantes
# Out:
# set([108])

# %%
print sorted(sobrantes)
# Out:
# [730, 964]

# %%
print sorted(faltantes)
# Out:
# [108]

# %%
print len(lista_pablo)
# Out:
# 250
